# %% [markdown]
# <a href="https://colab.research.google.com/github/jbazanr/Project1-part1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

# %%
df = pd.read_excel("/bostonHousing1978.xlsx")
df
# Out:
#         RM  LSTAT  PTRATIO  target
# 0    6.575   4.98     15.3    24.0
# 1    6.421   9.14     17.8    21.6
# 2    7.185   4.03     17.8    34.7
# 3    6.998   2.94     18.7    33.4
# 4    7.147   5.33     18.7    36.2
# ..     ...    ...      ...     ...
# 501  6.593   9.67     21.0    22.4
# 502  6.120   9.08     21.0    20.6
# 503  6.976   5.64     21.0    23.9
# 504  6.794   6.48     21.0    22.0
# 505  6.030   7.88     21.0    11.9
#
# [506 rows x 4 columns]

# %%
df2 = pd.read_csv("/mortgages.csv")
df2
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0         1         400000.00    1686.42        1000.00          686.42
# 1         2         399313.58    1686.42         998.28          688.14
# 2         3         398625.44    1686.42         996.56          689.86
# 3         4         397935.58    1686.42         994.83          691.59
# 4         5         397243.99    1686.42         993.10          693.32
# ...     ...               ...        ...            ...             ...
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 0       399313.58       30 Year           0.03
# ...

# %%
df2.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
df2.tail()
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 1075     12521.82       15 Year           0.05
# 1076      9410.82       15 Year           0.05
# 1077      6286.86       15 Year           0.05
# 1078      3149.88       15 Year           0.05
# 1079        -0.17       15 Year           0.05

# %%
df2.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# Mortgage Name        object
# Interest Rate       float64
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             1080 non-null   int64
#  1   Starting Balance  1080 non-null   float64
#  2   Repayment         1080 non-null   float64
#  3   Interest Paid     1080 non-null   float64
#  4   Principal Paid    1080 non-null   float64
#  5   New Balance       1080 non-null   float64
#  6   Mortgage Name     1080 non-null   object
#  7   Interest Rate     1080 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.6+ KB

# %%
df2[["Month"]]
# Out:
#       Month
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ...     ...
# 1075    176
# 1076    177
# 1077    178
# 1078    179
# 1079    180
#
# [1080 rows x 1 columns]

# %%
df2[["Month"]][21:28]
# Out:
#     Month
# 21     22
# 22     23
# 23     24
# 24     25
# 25     26
# 26     27
# 27     28

# %%
df2.loc[21:28,["Month"]]
# Out:
#     Month
# 21     22
# 22     23
# 23     24
# 24     25
# 25     26
# 26     27
# 27     28
# 28     29

# %%
dt3 = pd.read_csv("/mortgages.csv")
dt3
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0         1         400000.00    1686.42        1000.00          686.42
# 1         2         399313.58    1686.42         998.28          688.14
# 2         3         398625.44    1686.42         996.56          689.86
# 3         4         397935.58    1686.42         994.83          691.59
# 4         5         397243.99    1686.42         993.10          693.32
# ...     ...               ...        ...            ...             ...
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 0       399313.58       30 Year           0.03
# ...

# %%
dt3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             1080 non-null   int64
#  1   Starting Balance  1080 non-null   float64
#  2   Repayment         1080 non-null   float64
#  3   Interest Paid     1080 non-null   float64
#  4   Principal Paid    1080 non-null   float64
#  5   New Balance       1080 non-null   float64
#  6   Mortgage Name     1080 non-null   object
#  7   Interest Rate     1080 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 67.6+ KB

# %%
dt3["Mortgage Name"].value_counts()
# Out:
# 30 Year    720
# 15 Year    360
# Name: Mortgage Name, dtype: int64

# %%
filter=dt3["Mortgage Name"]=="15 Year"
filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1075     True
# 1076     True
# 1077     True
# 1078     True
# 1079     True
# Name: Mortgage Name, Length: 1080, dtype: bool

# %%
dt3[filter]
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 720       1         400000.00    2762.33        1000.00         1762.33
# 721       2         398237.67    2762.33         995.59         1766.74
# 722       3         396470.93    2762.33         991.17         1771.16
# 723       4         394699.77    2762.33         986.74         1775.59
# 724       5         392924.18    2762.33         982.31         1780.02
# ...     ...               ...        ...            ...             ...
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 720     398237.67       15 Year           0.03
# ...

# %%
filter2=dt3["Interest Rate"]==0.05

# %%
dt3[filter & filter2]
# Out:
#       Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 900       1         400000.00    3163.17        1666.66         1496.51
# 901       2         398503.49    3163.17        1660.43         1502.74
# 902       3         397000.75    3163.17        1654.16         1509.01
# 903       4         395491.74    3163.17        1647.88         1515.29
# 904       5         393976.45    3163.17        1641.56         1521.61
# ...     ...               ...        ...            ...             ...
# 1075    176          15619.91    3163.17          65.08         3098.09
# 1076    177          12521.82    3163.17          52.17         3111.00
# 1077    178           9410.82    3163.17          39.21         3123.96
# 1078    179           6286.86    3163.17          26.19         3136.98
# 1079    180           3149.88    3163.17          13.12         3150.05
#
#       New Balance Mortgage Name  Interest Rate
# 900     398503.49       15 Year           0.05
# ...

# %%
New_df = pd.read_csv("/Copia de diabetes.csv")
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
New_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
New_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
cero_embarazos = New_df["Pregnancies"].value_counts()
cero_embarazos
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64

# %%
dt4 = pd.read_csv("/content/drive/MyDrive/Dojo/Dataset/titanic.csv")
dt4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
